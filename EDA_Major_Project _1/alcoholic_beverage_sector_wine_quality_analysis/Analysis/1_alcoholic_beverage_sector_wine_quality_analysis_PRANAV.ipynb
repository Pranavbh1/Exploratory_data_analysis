# %% [markdown]
# # Case Study - Alcoholic Beverage Sector

# %% [markdown]
# ### Business Understanding

# %% [markdown]
# The wine industry is dynamic and diverse, with players ranging from small family-owned vineyards to large multinational corporations. It's influenced by factors such as regional climate, consumer preferences, government regulations, and global market trends. Additionally, it's a sector where tradition and innovation often intersect, as winemakers seek to balance time-honored practices with modern techniques and technologies.

# %% [markdown]
# ##### The quality of wine is important for several reasons, both for producers and consumers:

# %% [markdown]
# ##### 1.	Consumer Satisfaction:
# High-quality wine provides a better overall experience for consumers. It offers more enjoyable aromas, flavors, and textures, which can lead to greater satisfaction and enjoyment.

# %% [markdown]
# ##### 2.	Reputation and Branding:
# Consistently producing high-quality wine builds a positive reputation for wineries. This reputation can lead to brand loyalty, higher demand, and potentially higher prices for their products.

# %% [markdown]
# ##### 3.	Competitive Advantage:
#     In a crowded market, having a reputation for quality sets a winery apart from its competitors. It can attract more attention from distributors, retailers, and consumers.

# %% [markdown]
# ##### 4.	Wine Aging Potential:
#     High-quality wines typically have the structure and balance needed to age gracefully. They can develop more complex and nuanced flavors over time, increasing their value.

# %% [markdown]
# ##### 5.	Economic Value:
#     Collectors and investors often seek out high-quality wines for their potential to appreciate in value over time. Some rare or highly-rated wines can command very high prices in the market.

# %% [markdown]
# ##### 6.	Critical Acclaim:
#     High-quality wines are more likely to receive positive reviews and high scores from wine critics, which can significantly boost their visibility and demand.

# %% [markdown]
# ##### The chemical composition and sensory characteristics of wine play a significant role in determining its price.

# %% [markdown]
# The chemical composition and sensory characteristics of wine are two distinct aspects that provide valuable information about the nature and quality of a wine.

# %% [markdown]
# ## 1.	Chemical Composition:

# %% [markdown]
# The chemical composition of wine refers to the various compounds and elements present in the liquid. These include:

# %% [markdown]
# ##### ●	Fixed Acidity:
#     The total concentration of acids in the wine, which primarily includes tartaric acid, malic acid, and citric acid. It contributes to the wine's overall acidity level.

# %% [markdown]
# ##### ●	Volatile Acidity:
# The presence of volatile acids, primarily acetic acid, which can give a wine a vinegary or sharp taste if too high.

# %% [markdown]
# ##### ●	Citric Acid:
#     An organic acid naturally found in citrus fruits. It can add freshness and acidity to a wine.

# %% [markdown]
# ##### ●	Residual Sugar:
#     The amount of sugar that remains in the wine after fermentation. It influences the wine's sweetness level.

# %% [markdown]
# ##### ●	Chlorides:
#     The concentration of salts, particularly sodium chloride, which can affect the wine's taste and mouthfeel.

# %% [markdown]
# ##### ●	Free and Total Sulfur Dioxide:
# Sulfur dioxide is used in winemaking as a preservative and antioxidant. It can also affect the wine's aroma and flavor.

# %% [markdown]
# ##### ●	Density:
#     The mass per unit volume of the wine, which can indicate the concentration of solids (like sugar) in the liquid.

# %% [markdown]
# ##### ●	pH:
#     A measure of the wine's acidity or alkalinity. Lower pH values indicate higher acidity.

# %% [markdown]
# ##### ●	Sulphates:
#     Compounds that can act as antioxidants and antimicrobial agents in wine.

# %% [markdown]
# ##### ●	Alcohol:
#     The percentage of alcohol by volume in the wine, which affects the body, texture, and overall flavor profile.

# %% [markdown]
# ##### ●	Color (red/white):
#     This can be influenced by the grape variety used, as well as the winemaking process.

# %% [markdown]
# ## 2.	Sensory Characteristics:

# %% [markdown]
# Sensory characteristics refer to the aspects of wine that can be perceived by our senses, primarily taste and smell. These include:

# %% [markdown]
# ##### ●	Aroma:
#     The scents and fragrance perceived when smelling the wine. This can include fruity, floral, herbal, and other complex aromas.

# %% [markdown]
# ##### ●	Flavor:
# The combination of tastes experienced on the palate. This includes sweet, sour, bitter, salty, and umami, as well as various specific flavor notes.

# %% [markdown]
# ##### ●	Texture or Mouthfeel:
#     This includes factors like the wine's body (light, medium, full), tannin level (which affects astringency), and acidity (which affects freshness).

# %% [markdown]
# ##### ●	Finish:
#     The taste and sensation that lingers in the mouth after swallowing. It can be described as short, medium, or long.

# %% [markdown]
# ##### ●	Overall Quality:
#     The subjective assessment of how all these elements come together to create a pleasing or unpleasing experience for the taster.

# %% [markdown]
# Understanding both the chemical composition and sensory characteristics helps in evaluating and appreciating the wine, as well as in the production process for winemakers. It's worth noting that the balance and interaction between these elements contribute to the complexity and uniqueness of each wine.

# %% [markdown]
# # Wine Quality Dataset

# %% [markdown]
# ## Domain: Alcoholic Beverage Sector

# %% [markdown]
# #### Dataset description:

# %% [markdown]
# The dataset contains 6498 rows and 14 columns
# Input variables (based on physicochemical tests):

# %% [markdown]
# ##### ●	1 - fixed acidity

# %% [markdown]
# ##### ●	2 - volatile acidity

# %% [markdown]
# ##### ●	3 - citric acid

# %% [markdown]
# ##### ●	4 - residual sugar

# %% [markdown]
# ##### ●	5 - chlorides

# %% [markdown]
# ##### ●	6 - free sulfur dioxide

# %% [markdown]
# ##### ●	7 - total sulfur dioxide

# %% [markdown]
# ##### ●	8 - density

# %% [markdown]
# ##### ●	9 - pH

# %% [markdown]
# ##### ●	10 - sulphates

# %% [markdown]
# ##### ●	11 - alcohol

# %% [markdown]
# ##### ●	13- good(1/0)

# %% [markdown]
# ##### ●	14-Color(red/white)
# Output variable (based on sensory data):

# %% [markdown]
# ##### ●	12 - quality (score between 0 and 10)

# %% [markdown]
# # SPRINT 1 - Exploratory Data Analysis

# %% [markdown]
# ##### Task -
# This is an open ended question. Kindly apply all your knowledge to perform an exploratory data analysis on the given dataset. It is known that the target variable is Wine Quality.

# %% [markdown]
# However, you are mandatorily supposed to solve the below mentioned EDA Task for your presentation:
#
# 1.	Which variables are most significant with respect to the target variable?
#
# 2.	Explore the data distribution of each column. Identify some important patterns.
#
# 3.	Insights and Recommendations (i.e. Data Driven Business Decision)

# %% [markdown]
# ##### Write proper conclusions and provide recommendations to the bank based on the insights.

# %%
! pip install scipy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv('winequality.csv',parse_dates = True)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  good color
# 0      9.4        5     0   red
# ...

# %%
#good(1/0)
#quality (score between 0 and 10)
#Converting this both column to DISCRETE dtype 
df.quality = df['quality'].astype('object')
df.good = df.good.astype('object')

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'good', 'color'],
#       dtype='object')

# %%
df.shape
# Out:
# (6497, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   object
#  12  good                  6497 non-null   object
#  13  color                 6497 non-null   object
# dtypes: float64(11), object(3)
# ...

# %%
#Cleaning and renaming columns names
col_names = [col.lower().replace(' ','_').strip() for col in df.columns]
df.columns = col_names
df.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'ph', 'sulphates', 'alcohol', 'quality', 'good', 'color'],
#       dtype='object')

# %%
df.isnull().sum()
#Luckily in our dataset their is no missing values .
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# ph                      0
# sulphates               0
# alcohol                 0
# quality                 0
# good                    0
# color                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'ph', 'sulphates', 'alcohol', 'quality', 'good', 'color'],
#       dtype='object')

# %%
fig,axes = plt.subplots(2,5)

# %%
df.ph.plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Checking for outliers :

# %%
discrete_df = df.select_dtypes(include=['object'])

numerical_df = df.select_dtypes(include=['int64', 'float64'])
#nuerical_df were in g/dm³

# %%
discrete_df.shape
# Out:
# (6497, 3)

# %%
numerical_df.shape
# Out:
# (6497, 11)

# %%
# groupby on discrete(categorical) column i.e. on 'quality'
group1 = df.groupby('quality')

# %%
# Bar Plots on Discrerte col
#fixed_acidity V/S quality
print(group1['fixed_acidity'].agg(['min' , 'max' , 'mean' , 'median']))
df.boxplot(by= 'quality', column = "fixed_acidity")
# Out:
#          min   max      mean  median
# quality
# 3        4.2  11.8  7.853333    7.45
# 4        4.6  12.5  7.288889    7.00
# 5        4.5  15.9  7.326801    7.10
# 6        3.8  14.3  7.177257    6.90
# 7        4.2  15.6  7.128962    6.90
# 8        3.9  12.6  6.835233    6.80
# 9        6.6   9.1  7.420000    7.10
# <Axes: title={'center': 'fixed_acidity'}, xlabel='quality'>

# %%
df.fixed_acidity.plot(kind = 'box')
# Out:
# <Axes: >

# %%
# Bar Plots on Discrerte col
#volatile_acidity V/S quality
print(group1['fixed_acidity'].agg(['min' , 'max' , 'mean' , 'median']))
df.boxplot(by= 'quality', column = "volatile_acidity")
# Out:
#          min   max      mean  median
# quality
# 3        4.2  11.8  7.853333    7.45
# 4        4.6  12.5  7.288889    7.00
# 5        4.5  15.9  7.326801    7.10
# 6        3.8  14.3  7.177257    6.90
# 7        4.2  15.6  7.128962    6.90
# 8        3.9  12.6  6.835233    6.80
# 9        6.6   9.1  7.420000    7.10
# <Axes: title={'center': 'volatile_acidity'}, xlabel='quality'>

# %%
# Bar Plots on Discrerte col
#volatile_acidity V/S quality
print(group1['fixed_acidity'].agg(['min' , 'max' , 'mean' , 'median']))
df.boxplot(by= 'quality', column = "volatile_acidity")
# Out:
#          min   max      mean  median
# quality
# 3        4.2  11.8  7.853333    7.45
# 4        4.6  12.5  7.288889    7.00
# 5        4.5  15.9  7.326801    7.10
# 6        3.8  14.3  7.177257    6.90
# 7        4.2  15.6  7.128962    6.90
# 8        3.9  12.6  6.835233    6.80
# 9        6.6   9.1  7.420000    7.10
# <Axes: title={'center': 'volatile_acidity'}, xlabel='quality'>

# %%
numerical_df.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'ph', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
discrete_df.columns
# Out:
# Index(['quality', 'good', 'color'], dtype='object')

# %%
fig, axs = plt.subplots(11,1, figsize=(10,30), layout="constrained")
fig.suptitle("Visual bivariate Analysis - Numerical V/S Categorical Features")

cols = numerical_df.columns
cols1 = discrete_df.columns

for idx, ax in enumerate(axs):
    col_name = cols1[idx]
#     df.boxplot(by= 'cols1', column = "cols")
    sns.boxplot(data = df[cols] , x = df[col_name] , ax = axs[idx])


#     ax[0].boxplot(df[col_name])
#     ax[0].set_title("Histogram Plot - " + col_name)
#     ax[0].set_ylabel("Frequency")
#     sns.kdeplot(data = numerical_df , x = df[col_name] , ax = ax[1])
# #     ax[0].KDE(df[col_name])
    
#     ax[2].boxplot(df[col_name])
#     ax[2].set_title("Box Plot - " + col_name)
#     sns.boxenplot(data=numerical_df, x=df[col_name], ax=ax[3])
#     sns.violinplot(data=numerical_df, x=df[col_name], ax=ax[4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 10
#       8     col_name = cols1[idx]
#       9 #     df.boxplot(by= 'cols1', column = "cols")
# ---> 10     sns.boxplot(data = df[cols] , x = df[col_name] , ax = axs[idx])
#
# File ~\anaconda\Lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
# ...

# %% [markdown]
# # 1. Univariate Analysis - Statistical Non Visual Analysis

# %%
discrete_df = df.select_dtypes(include=['object'])

numerical_df = df.select_dtypes(include=['int64', 'float64'])
#nuerical_df were in g/dm³

# %%
def discrete_univariate_analysis(discrete_data):
  for col_name in discrete_data:
    print("*"*10, col_name, "*"*10)
    print(discrete_data[col_name].agg(['count', 'nunique', 'unique']))
    print('Value Counts: \n', discrete_data[col_name].value_counts())
    print()

# %%
discrete_univariate_analysis(discrete_df)
# Out:
# ********** quality **********
# count                       6497
# nunique                        7
# unique     [5, 6, 7, 4, 8, 3, 9]
# Name: quality, dtype: object
# Value Counts:
#  quality
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: count, dtype: int64
#
# ********** good **********
# count        6497
# nunique         2
# unique     [0, 1]
# Name: good, dtype: object
# Value Counts:
#  good
# 0    5220
# 1    1277
# Name: count, dtype: int64
#
# ********** color **********
# count              6497
# nunique               2
# unique     [red, white]
# Name: color, dtype: object
# Value Counts:
#  color
# white    4898
# red      1599
# Name: count, dtype: int64

# %%
def numerical_univariate_analysis(numerical_data):
  for col_name in numerical_data:
    print("*"*10, col_name, "*"*10)
    print(numerical_data[col_name].agg(['min', 'max', 'mean', 'median', 'std']))
    print()

# %%
numerical_univariate_analysis(numerical_df)
# Out:
# ********** fixed_acidity **********
# min        3.800000
# max       15.900000
# mean       7.215307
# median     7.000000
# std        1.296434
# Name: fixed_acidity, dtype: float64
#
# ********** volatile_acidity **********
# min       0.080000
# max       1.580000
# mean      0.339666
# median    0.290000
# std       0.164636
# Name: volatile_acidity, dtype: float64
#
# ********** citric_acid **********
# min       0.000000
# max       1.660000
# mean      0.318633
# median    0.310000
# std       0.145318
# Name: citric_acid, dtype: float64
#
# ********** residual_sugar **********
# min        0.600000
# max       65.800000
# mean       5.443235
# median     3.000000
# std        4.757804
# Name: residual_sugar, dtype: float64
#
# ********** chlorides **********
# min       0.009000
# max       0.611000
# mean      0.056034
# median    0.047000
# std       0.035034
# Name: chlorides, dtype: float64
#
# ********** free_sulfur_dioxide **********
# min         1.000000
# ...

# %%
discrete_univariate_analysis(discrete_df)
# Out:
# ********** quality **********
# count                       6497
# nunique                        7
# unique     [5, 6, 7, 4, 8, 3, 9]
# Name: quality, dtype: object
# Value Counts:
#  quality
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: count, dtype: int64
#
# ********** good **********
# count        6497
# nunique         2
# unique     [0, 1]
# Name: good, dtype: object
# Value Counts:
#  good
# 0    5220
# 1    1277
# Name: count, dtype: int64
#
# ********** color **********
# count              6497
# nunique               2
# unique     [red, white]
# Name: color, dtype: object
# Value Counts:
#  color
# white    4898
# red      1599
# Name: count, dtype: int64

# %% [markdown]
# # 2. Univariate Visual Analysis

# %%
numerical_df.shape
# Out:
# (6497, 11)

# %%
# Histograms and KDE plots and Box Plots and Boxen Plots and Violin Plots on Numerical dtypes Columns

fig, axs = plt.subplots(11,5, figsize=(10,30), layout="constrained")
fig.suptitle("Visual Univariate Analysis - Numerical Features")

cols = numerical_df.columns

for idx, ax in enumerate(axs):
    col_name = cols[idx]
    ax[0].hist(df[col_name])
    ax[0].set_title("Histogram Plot - " + col_name)
    ax[0].set_ylabel("Frequency")
    sns.kdeplot(data = numerical_df , x = df[col_name] , ax = ax[1])
#     ax[0].KDE(df[col_name])
    
    ax[2].boxplot(df[col_name])
    ax[2].set_title("Box Plot - " + col_name)
    sns.boxenplot(data=numerical_df, x=df[col_name], ax=ax[3])
    sns.violinplot(data=numerical_df, x=df[col_name], ax=ax[4])

# %%
discrete_df.shape
# Out:
# (6497, 3)

# %% [markdown]
# # Univariate Plotting For Categorical Columns - Count Plot

# %%
# Bar Plots on Discrerte col

fig, axs = plt.subplots(1,3, figsize=(6, 3), layout="constrained")
fig.suptitle("Visual Univariate Analysis - Categorical Features")

cols = discrete_df.columns

for idx, ax in enumerate(axs.ravel()):
    col_name = cols[idx]
    data = df[col_name].value_counts()
    ax.bar(data.index, data.values)
    ax.set_title("Bar Plot - " + col_name)
    ax.set_ylabel("Frequency")

# %%
# Horizontal Bar Plots

fig, axs = plt.subplots(1,3, figsize=(10, 5), layout="constrained")
fig.suptitle("Visual Univariate Analysis - Categorical Features")

cols = discrete_df.columns

for idx, ax in enumerate(axs.ravel()):
    col_name = cols[idx]
    data = df[col_name].value_counts()
    ax.barh(data.index, data.values)
    ax.set_title("Bar Plot - " + col_name)
    ax.set_ylabel("Frequency")

# %%
numerical_df.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'ph', 'sulphates', 'alcohol'],
#       dtype='object')

# %% [markdown]
# # Bivariate Analysis - Non Visual and Visual Analysis

# %%
numerical_df.corr()
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000          0.219008     0.324436
# volatile_acidity           0.219008          1.000000    -0.377981
# citric_acid                0.324436         -0.377981     1.000000
# residual_sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free_sulfur_dioxide       -0.282735         -0.352557     0.133126
# total_sulfur_dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# ph                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# fixed_acidity              -0.111981   0.298195            -0.282735
# ...

# %%
fig, ax = plt.subplots(figsize=(10,10))
fig.suptitle("Heat Map")

ax.set_title("Pearson Correlation Coefficients", loc="left", fontsize="small")
ax = sns.heatmap(numerical_df.corr(), annot=True, linewidths=0.5)

plt.show()

# %%
discrete_df.columns
# Out:
# Index(['quality', 'good', 'color'], dtype='object')

# %%
tab = pd.crosstab(discrete_df['quality'], discrete_df['good'], normalize='index')

tab
# Out:
# good       0    1
# quality
# 3        1.0  0.0
# 4        1.0  0.0
# 5        1.0  0.0
# 6        1.0  0.0
# 7        0.0  1.0
# 8        0.0  1.0
# 9        0.0  1.0

# %%
tab = pd.crosstab(discrete_df['quality'], discrete_df['color'], normalize='index')

tab
# Out:
# color         red     white
# quality
# 3        0.333333  0.666667
# 4        0.245370  0.754630
# 5        0.318522  0.681478
# 6        0.224965  0.775035
# 7        0.184430  0.815570
# 8        0.093264  0.906736
# 9        0.000000  1.000000

# %%
tab = pd.crosstab(discrete_df['good'], discrete_df['color'], normalize='index')

tab
# Out:
# color       red     white
# good
# 0      0.264751  0.735249
# 1      0.169930  0.830070

# %%
tab.plot(kind='bar', stacked=True)

plt.title("Stacked Bar Plot")
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.05, 1))

plt.show()

# %% [markdown]
# # Q-Q plot for every continous col :

# %%
numerical_df.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'ph', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
stats.probplot(numerical_df.fixed_acidity , dist = 'norm' , plot = plt)
# Out:
# ((array([-3.70264522, -3.47132216, -3.34402621, ...,  3.34402621,
#           3.47132216,  3.70264522]),
#   array([ 3.8,  3.9,  4.2, ..., 15.6, 15.6, 15.9])),
#  (1.2164119552333013, 7.215307064799139, 0.9378526938405135))

# %%
numerical_df.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'ph', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
norm =

# %%
fig , axes = plt.subplots(2,5,figsize = (5,3),constrained_layout = True)
plt.suptitle("Q-Q Plot for all Numerical column")

stats.probplot(numerical_df.fixed_acidity , dist = 'norm' , plot = axes[0])
axes[0].grid()

stats.probplot(numerical_df.volatile_acidity , dist = 'norm' , plot = axes[1])
axes[1].grid()

stats.probplot(numerical_df.citric_acid , dist = 'norm' , plot = axes[2])
axes[2].grid()

stats.probplot(numerical_df.residual_sugar , dist = 'norm' , plot = axes[3])
axes[3].grid()

stats.probplot(numerical_df.chlorides , dist = 'norm' , plot = axes[4])
axes[4].grid()

stats.probplot(numerical_df.free_sulfur_dioxide , dist = 'norm' , plot = axes[5])
axes[5].grid()

stats.probplot(numerical_df.total_sulfur_dioxide , dist = 'norm' , plot = axes[6])
axes[6].grid()

stats.probplot(numerical_df.density , dist = 'norm' , plot = axes[7])
axes[7].grid()

stats.probplot(numerical_df.ph , dist = 'norm' , plot = axes[8])
axes[8].grid()

stats.probplot(numerical_df.sulphates , dist = 'norm' , plot = axes[9])
axes[9].grid()

stats.probplot(numerical_df.alcohol , dist = 'norm' , plot = axes[10])
axes[10].grid()

plt.show()

# cols = numerical_df.columns
#     stats.probplot(col_name , dist = 'norm' , plot = plt)

# for idx, ax in enumerate(axs.ravel()):
#     col_name = cols[idx]
# plt.grid()

#     data = df[col_name].value_counts()
#     ax.bar(data.index, data.values)
#     ax.set_title("Bar Plot - " + col_name)
#     ax.set_ylabel("Frequency")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 4
#       1 fig , axes = plt.subplots(2,5,figsize = (5,3),constrained_layout = True)
#       2 plt.suptitle("Q-Q Plot for all Numerical column")
# ----> 4 stats.probplot(numerical_df.fixed_acidity , dist = 'norm' , plot = axes[0])
#       5 axes[0].grid()
#       7 stats.probplot(numerical_df.volatile_acidity , dist = 'norm' , plot = axes[1])
#
# File ~\anaconda\Lib\site-packages\scipy\stats\_morestats.py:625, in probplot(x, sparams, dist, fit, plot, rvalue)
#     622     slope, intercept, r, prob, _ = _stats_py.linregress(osm, osr)
#     624 if plot is not None:
# --> 625     plot.plot(osm, osr, 'bo')
#     626     if fit:
#     627         plot.plot(osm, slope*osm + intercept, 'r-')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
n = int(input())
for i in range(n,1,-1):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 n = int(input())
#       2 for i in range(n,1,-1):
#       3     print(i)
#
# File ~\anaconda\Lib\site-packages\ipykernel\kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
# -> 1175 return self._input_request(
#    1176     str(prompt),
#    1177     self._parent_ident["shell"],
#    1178     self.get_parent("shell"),
#    1179     password=False,
#    1180 )
#
# File ~\anaconda\Lib\site-packages\ipykernel\kernelbase.py:1217, in Kernel._input_request(self, prompt, ident, parent, password)
#    1214             break
#    1215 except KeyboardInterrupt:
# ...

# %% [markdown]
# # What is the ratio of each type of wine based on quality scale 1 to 10 ?

# %%
df.head()

# %%
df.columns

# %%
pie_quality = df.quality.value_counts(normalize = True)
pie_quality

# %%
plt.pie(pie_quality.values , labels = pie_quality.index , autopct = '%1.1f%%' )
plt.set_title("Quality-Pie Plot" , fontsize = 'medium')
plt.show()

# %%
# Initializing a figure (without axes)
fig = plt.figure(figsize=(3, 3), facecolor='lightskyblue')

# Adding Axes (Generates 1 axes or subplot)
ax = fig.add_subplot()

# Display the Figure
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,10), layout="constrained")
fig.suptitle("Univariate Plotting - Categorical Features")

pie_quality = df.quality.value_counts()
axs[0].bar(pie_quality.index, pie_quality.values)
axs[0].set_title("Bar Plot", fontsize="medium")

pie_quality_normalised = df.quality.value_counts(normalize = True)
explode = (0.1, 0, 0, 0, 0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

axs[1].pie(pie_quality_normalised.values,explode=explode, labels=pie_quality_normalised.index, autopct='%1.1f%%' , pctdistance=1.25, labeldistance=.6 , )
axs[1].set_title("Pie Plot", fontsize="small")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ['6','5','7','4','8','3','9']

data = [43.6 , 32.9 , 16.6 , 3.32 , 2.9 , 0.4 , 0.07]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = f"angle,angleA=0,angleB={ang}"
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.50*np.sign(x), 4.0*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Quality -Donut plot")

plt.show()

# %%
import matplotlib.pyplot as plt
 
# Setting labels for items in Chart
Employee = ['6','5','7','4','8','3','9']
 
# Setting size in Chart based on 
# given values
Salary = [43.6 , 32.9 , 16.6 , 3.3 , 2.9 , 0.4 , 0.07]
 
# colors
colors = ['#FF0000', '#0000FF', '#FFFF00', 
          '#ADFF2F', '#FFA500']
# explosion
explode = (0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05)
 
# Pie Chart
plt.pie(Salary, colors=colors, labels=Employee,
        autopct='%1.1f%%', pctdistance=0.85,
        explode=explode,)
 
# draw circle
centre_circle = plt.Circle((10, 10), 0.10, fc='white')
fig = plt.gcf()
 
# Adding Circle in Pie chart
fig.gca().add_artist(centre_circle)
 
# Adding Title of chart
plt.title('Employee Salary Details')
 
# Displaying Chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ["375 g flour",
          "75 g sugar",
          "250 g butter",
          "300 g berries"]

data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d} g)"


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Ingredients",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Matplotlib bakery: A pie")

plt.show()

# %%
pie_quality = df.quality.value_counts(normalize = True)
pie_quality

# %%
import matplotlib.pyplot as plt

labels = '6','5','7','4','8','3','9'
sizes = [43.6 , 35.9 , 16.6 , 3.3 , 2.9 , 0.4 , 0.07]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

# %%
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%',
       pctdistance=1.25, labeldistance=.6)

# %%
explode = (0.1, 0, 0, 0, 0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig, ax = plt.subplots(figsize = (10,20))
ax.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
       shadow=True, startangle=90)
plt.show()

# %%
fig, ax = plt.subplots()

ax.pie(sizes, labels=labels, autopct='%.0f%%',
       textprops={'size': 'large'}, radius=1.0 , shadow={'ox': -0.04, 'edgecolor': 'none', 'shade': 0.9}, startangle=90)
plt.show()

# %%
fig, ax = plt.subplots()
ax.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
       shadow={'ox': -0.04, 'edgecolor': 'none', 'shade': 0.9}, startangle=90)
plt.show()

# %%
pie_quality_normalised = df.quality.value_counts(normalize = True)
axs[1].pie(pie_quality_normalised.values, labels=pie_quality_normalised.index, autopct='%1.1f%%')
axs[1].set_title("Pie Plot", fontsize="large")

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, hatch=['**O', 'oO', 'O.O', '.||.'])

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%',
       pctdistance=1.25, labeldistance=.6)

explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig, ax = plt.subplots()
ax.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
       shadow=True, startangle=90)
plt.show()

fig, ax = plt.subplots()
ax.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
       shadow={'ox': -0.04, 'edgecolor': 'none', 'shade': 0.9}, startangle=90)
plt.show()

# %%
fig = plt.subplots( figsize=(6, 3), layout="constrained" , facecolor='lightskyblue')
# fig.set_title("Univariate Plotting - Categorical Features")

# bar_plt_data = df["col_2"].value_counts()
# axs[0].bar(bar_plt_data.index, bar_plt_data.values)
# axs[0].set_title("Bar Plot", fontsize="medium")
ax = fig.subplots()
pie_quality_normalised = df.quality.value_counts(normalize = True)
ax.pie(pie_quality_normalised.values, labels=pie_quality_normalised.index, autopct='%1.1f%%')
ax.set_title("Quality - Pie Plot", fontsize="medium")

plt.show()
